# %%
import pandas as pd
df_url = pd.read_excel('DataUrl.xlsx')
df_url
# Out:
#                                              URL BASE  Numero  \
# 0   https://www.camara.cl/legislacion/sala_sesione...   33135
# 1   https://www.camara.cl/legislacion/sala_sesione...   33134
# 2   https://www.camara.cl/legislacion/sala_sesione...   33133
# 3   https://www.camara.cl/legislacion/sala_sesione...   33132
# 4   https://www.camara.cl/legislacion/sala_sesione...   33131
# ..                                                ...     ...
# 95  https://www.camara.cl/legislacion/sala_sesione...   33040
# 96  https://www.camara.cl/legislacion/sala_sesione...   33039
# 97  https://www.camara.cl/legislacion/sala_sesione...   33038
# 98  https://www.camara.cl/legislacion/sala_sesione...   33037
# 99  https://www.camara.cl/legislacion/sala_sesione...   33036
#
#                                             Resultado     Sesion  Unnamed: 4
# 0   https://www.camara.cl/legislacion/sala_sesione...    Sesion1           1
# 1   https://www.camara.cl/legislacion/sala_sesione...    Sesion2           2
# 2   https://www.camara.cl/legislacion/sala_sesione...    Sesion3           3
# 3   https://www.camara.cl/legislacion/sala_sesione...    Sesion4           4
# 4   https://www.camara.cl/legislacion/sala_sesione...    Sesion5           5
# ..                                                ...        ...         ...
# 95  https://www.camara.cl/legislacion/sala_sesione...   Sesion96          96
# 96  https://www.camara.cl/legislacion/sala_sesione...   Sesion97          97
# 97  https://www.camara.cl/legislacion/sala_sesione...   Sesion98          98
# 98  https://www.camara.cl/legislacion/sala_sesione...   Sesion99          99
# 99  https://www.camara.cl/legislacion/sala_sesione...  Sesion100         100
#
# [100 rows x 5 columns]

# %%
import requests
import urllib.request
from bs4 import BeautifulSoup

diputados_1=[]
diputados_2 = []
diputados_final_a_favor=[]
diputados_final_en_contra=[]
datafinal=[]


url = df_url.loc[0].at['Resultado']
r = requests.get(url)
html_content = r.text
soup = BeautifulSoup(html_content,"lxml")
table = soup.find('table',id='ContentPlaceHolder1_ContentPlaceHolder1_PaginaContent_dtlAFavor')
titulo = df_url.loc[0].at['Sesion']
#subti = titulo.div.info.text.strip()
filas = table.find_all('tr')
#colum = table.find_all('td')
for fila in filas:
    colum = fila.find_all('td')
    fil = [fila.text.strip() for fila in colum if fila.text.strip()]
    #print()
    #diputados.append(col_0.replace('\r',''))
    if fil:
        diputados_1.append(fil)
    
for i in diputados_1:
    for a in i:
        diputados_final_a_favor.append(a)

print(diputados_final_a_favor)

##################################################################

table_1 = soup.find('table',id='ContentPlaceHolder1_ContentPlaceHolder1_PaginaContent_dtlEnContra')
filas_1 = table_1.find_all('tr')
#colum = table.find_all('td')
for fila_1 in filas_1:
    colum_1 = fila_1.find_all('td')
    fil_1 = [fila_1.text.strip() for fila_1 in colum_1 if fila_1.text.strip()]
    #print()
    #diputados.append(col_0.replace('\r',''))
    if fil_1:
        diputados_2.append(fil)

          
      
for h in diputados_2:
    for b in h:
        diputados_final_en_contra.append(b)
    
print(diputados_final_en_contra)
print(len(diputados_final_a_favor)+len(diputados_final_en_contra))
# Out:
# ['Alessandri Vergara, Jorge', 'Hernández Hernández, Javier', 'Pérez Lahsen, Leopoldo', 'Álvarez Ramírez, Sebastián', 'Hernando Pérez, Marcela', 'Pérez Olea, Joanna', 'Alvarez-Salamanca Ramírez, Pedro Pablo', 'Hoffmann Opazo, María José', 'Pérez Salinas, Catalina', 'Amar Mancilla, Sandra', 'Jarpa Wevar, Carlos Abel', 'Prieto Lorca, Pablo', 'Ascencio Mansilla, Gabriel', 'Jürgensen Rundshagen, Harry', 'Ramírez Diez, Guillermo', 'Auth Stewart, Pepe', 'Kast Sommerhoff, Pablo', 'Rathgeb Schifferli, Jorge', 'Baltolu Rasera, Nino', 'Keitel Bianchi, Sebastián', 'Rentería Moller, Rolando', 'Barros Montero, Ramón', 'Kort Garriga, Issa', 'Rey Martínez, Hugo', 'Bellolio Avaria, Jaime', 'Kuschel Silva, Carlos', 'Romero Sáez, Leonidas', 'Berger Fett, Bernardo', 'Lavín León, Joaquín', 'Sabag Villalobos, Jorge', 'Bianchi Retamales, Karim', 'Leuquén Uribe, Aracely', 'Sabat Fernández, Marcela', 'Bobadilla Muñoz, Sergio', 'Longton Herrera, Andrés', 'Sanhueza Dueñas, Gustavo', 'Calisto Águila, Miguel Ángel', 'Luck Urban, Karin', 'Santana Tirachini, Alejandro', 'Carter Fernández, Álvaro', 'Macaya Danús, Javier', 'Sauerbaum Muñoz, Frank', 'Castro Bascuñán, José Miguel', 'Melero Abaroa, Patricio', 'Schalper Sepúlveda, Diego', 'Celis Montt, Andrés', 'Mellado Pino, Cosme', 'Sepúlveda Soto, Alexis', 'Cid Versalovic, Sofía', 'Mellado Suazo, Miguel', 'Silber Romo, Gabriel', 'Coloma Álamos, Juan Antonio', 'Meza Moncada, Fernando', 'Tohá González, Jaime', 'Crispi Serrano, Miguel', 'Molina Magofke, Andrés', 'Torrealba Alvarado, Sebastián', 'Cruz-Coke Carvallo, Luciano', 'Morales Muñoz, Celso', 'Torres Jeldes, Víctor', 'Del Real Mihovilovic, Catalina', 'Moreira Barros, Cristhian', 'Trisotti Martínez, Renzo', 'Desbordes Jiménez, Mario', 'Muñoz González, Francesca', 'Troncoso Hellman, Virginia', 'Durán Espinoza, Jorge', 'Noman Garrido, Nicolás', 'Undurraga Gazitúa, Francisco', 'Durán Salinas, Eduardo', 'Norambuena Farías, Iván', 'Urrutia Bonilla, Ignacio', 'Eguiguren Correa, Francisco', 'Núñez Urrutia, Paulina', 'Urrutia Soto, Osvaldo', 'Flores García, Iván', 'Olivera De La Fuente, Erika', 'Urruticoechea Ríos, Cristóbal', 'Flores Oporto, Camila', 'Orsini Pascal, Maite', 'Van Rysselberghe Herrera, Enrique', 'Fuenzalida Cobo, Juan', 'Ortiz Novoa, José Miguel', 'Velásquez Seguel, Pedro', 'Fuenzalida Figueroa, Gonzalo', 'Ossandón Irarrázabal, Ximena', 'Venegas Cárdenas, Mario', 'Gahona Salazar, Sergio', 'Pardo Sáinz, Luis', 'Verdessi Belemmi, Daniel', 'Galleguillos Castillo, Ramón', 'Paulsen Kehr, Diego', 'Von Mühlenbrock Zamora, Gastón', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías']
# ['García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías', 'García García, René Manuel', 'Pérez Arriagada, José', 'Walker Prieto, Matías']
# 150

# %%
df_1 = pd.DataFrame(diputados_final_a_favor,columns=["Nombre Diputado"])
df_1['Voto'] = 1
df_2 = pd.DataFrame(diputados_final_en_contra,columns=["Nombre Diputado"])
df_2['Voto'] = 0
frames = [df_1,df_2]
eljunte = pd.concat(frames)
eljunte['Sesion'] = titulo

#datafinal.append(eljunte)
eljunte.tail()
eljunte.to_excel(r'C:\Users\Usuario\Desktop\Data science\Proyecto Frente Amplio\ejemplojuaco.xlsx')
